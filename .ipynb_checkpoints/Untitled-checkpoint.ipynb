# %%
import ResilAssembler
import qgrid
# Out:
# /Users/skoebric/Dropbox/GitHub/Resil Dashboard/ResilDashboard.py:458: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df = pd.concat(s_list, axis = 1)[-10:]
# ...
